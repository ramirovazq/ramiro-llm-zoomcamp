# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role":"user", "content": "is it too late to join the course?"}
    ]
)

# %%
response.choices[0].message
# Out:
# ChatCompletionMessage(content="I would need more specific information to answer your question accurately. It depends on the course you're referring to, including factors such as the course start date, enrollment deadlines, and whether the course allows late registration. If you provide additional details—like the name of the course or the institution offering it—I might be able to offer more guidance. Alternatively, you could contact the course provider directly for the most accurate information.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)

# %%
#!wget https://raw.githubusercontent.com/alexeygrigorev/minsearch/refs/heads/main/minsearch.py
# Out:
# --2026-04-02 14:03:03--  https://raw.githubusercontent.com/alexeygrigorev/minsearch/refs/heads/main/minsearch.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4404 (4.3K) [text/plain]
# Saving to: ‘minsearch.py’
#
# minsearch.py        100%[===================>]   4.30K  --.-KB/s    in 0s
#
# 2026-04-02 14:03:03 (39.6 MB/s) - ‘minsearch.py’ saved [4404/4404]

# %%
import minsearch

# %%
import json

# %%
with open('parse/documents.json', 'rt') as f_in:
    docs_raw = json.load(f_in)

# %%
documents = []

for course_dict in docs_raw:
    for doc in course_dict['documents']:
        doc['course']= course_dict['course']
        documents.append(doc)
print(documents[20])
# Out:
# {'text': 'When you set up your account you are automatically assigned a random name such as “Lucid Elbakyan” for example. If you want to see what your Display name is.\nGo to your profile:  →\n2025: https://courses.datatalks.club/de-zoomcamp-2025/enrollment\n2024: https://courses.datatalks.club/de-zoomcamp-2024/enrollment \n\nLog in -> your display name is here, you can also change it should you wish. Make sure your Certificate name is correct, this name will later be printed on your certificate!!!', 'section': 'Course Management Platform for Homeworks, Project and Certificate', 'question': 'Leaderboard - I am not on the leaderboard / how do I know which one I am on the leaderboard?', 'course': 'data-engineering-zoomcamp'}

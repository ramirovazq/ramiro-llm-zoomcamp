# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role":"user", "content": "is it too late to join the course?"}
    ]
)

# %%
response.choices[0].message
# Out:
# ChatCompletionMessage(content="To provide an accurate answer, I would need more information, such as the specific course you are referring to and its schedule or enrollment deadlines. If you have details about the course start date or registration period, it's best to check with the course provider directly to see if they are still accepting enrollments. If it's an online course, sometimes there is more flexibility with start dates.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/minsearch/refs/heads/main/minsearch.py
# Out:
# --2026-04-02 14:03:03--  https://raw.githubusercontent.com/alexeygrigorev/minsearch/refs/heads/main/minsearch.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4404 (4.3K) [text/plain]
# Saving to: ‘minsearch.py’
#
# minsearch.py        100%[===================>]   4.30K  --.-KB/s    in 0s
#
# 2026-04-02 14:03:03 (39.6 MB/s) - ‘minsearch.py’ saved [4404/4404]

# %%
import minsearch
